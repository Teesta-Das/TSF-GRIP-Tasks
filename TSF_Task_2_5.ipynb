# %% [markdown]
# <a href="https://colab.research.google.com/github/Teesta-Das/TSF-GRIP-Tasks/blob/main/TSF_Task_2_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Name-Teesta Das**
# # **#5 of Task 2- Exploratory Data Analysis Task:**
# # **To Explore Business Analytics**

# %% [markdown]
# **In this task, we shall be performing Exploratory Data Analysis on a given dataset 'SampleSuperstore' and, as a business manager, try to find out the weak areas where we can work to make more profit.**

# %%
# We import the necessary python libraries for the notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# We upload the csv file and create an instance, say df, to read the dataset

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-7327f0e5-bd69-460d-a974-7dd6e1983e49" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7327f0e5-bd69-460d-a974-7dd6e1983e49">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving SampleSuperstore.csv to SampleSuperstore.csv

# %%
df=pd.read_csv('SampleSuperstore.csv')
df
# Out:
#            Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0       Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1       Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2       Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3     Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4     Standard Class   Consumer  United States  ...        2     0.20    2.5164
# ...              ...        ...            ...  ...      ...      ...       ...
# 9989    Second Class   Consumer  United States  ...        3     0.20    4.1028
# 9990  Standard Class   Consumer  United States  ...        2     0.00   15.6332
# 9991  Standard Class   Consumer  United States  ...        2     0.20   19.3932
# 9992  Standard Class   Consumer  United States  ...        4     0.00   13.3200
# 9993    Second Class   Consumer  United States  ...        2     0.00   72.9480
#
# ...

# %%
# Let us try to get some basic information about the dataset

# %%
df.shape # Gives the number of rows and columns in the dataset
# Out:
# (9994, 13)

# %%
df.columns # Gives all the columns of the dataset
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.info() # Gives information about the entire dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe() # Gives the statistical information about the dataset
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ### **Data Cleaning-**

# %%
df.isnull().sum() # We check if there are any missing values in the dataset
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# Apparently, there are no missing values in the dataset.

# %%
# We check if there are any duplicate values in the dataset

# %%
df.duplicated().sum()
# Out:
# 17

# %% [markdown]
# So, there are 17 duplicate values in the dataset which we need to remove.

# %%
df=df.drop_duplicates() # We are modifying the dataset by removing the duplicate values
df
# Out:
#            Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0       Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1       Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2       Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3     Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4     Standard Class   Consumer  United States  ...        2     0.20    2.5164
# ...              ...        ...            ...  ...      ...      ...       ...
# 9989    Second Class   Consumer  United States  ...        3     0.20    4.1028
# 9990  Standard Class   Consumer  United States  ...        2     0.00   15.6332
# 9991  Standard Class   Consumer  United States  ...        2     0.20   19.3932
# 9992  Standard Class   Consumer  United States  ...        4     0.00   13.3200
# 9993    Second Class   Consumer  United States  ...        2     0.00   72.9480
#
# ...

# %%
df.shape # Gives the number of rows and columns of the modified dataset
# Out:
# (9977, 13)

# %% [markdown]
# **We shall now be working with the modified dataset.**

# %% [markdown]
# ## **Now that we have a general idea about the dataset, we shall proceed to the Graphical Representations of the data in order to draw valuable insights from them:**

# %% [markdown]
# ## **Plotting relation among the different variables:**

# %%
# Correlation matrix: Gives the internal relations among the numerical variables of the dataset
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023476  0.013110  0.059225 -0.029892
# Sales          -0.023476  1.000000  0.200722 -0.028311  0.479067
# Quantity        0.013110  0.200722  1.000000  0.008678  0.066211
# Discount        0.059225 -0.028311  0.008678  1.000000 -0.219662
# Profit         -0.029892  0.479067  0.066211 -0.219662  1.000000

# %%
# We plot a heatmap to represent the correlation matrix
sns.heatmap(df.corr())

# %%
# We plot the pairwise relationships among the different variables of the dataset using a pairplot
sns.pairplot(df)

# %% [markdown]
# ## **Distribution of the Numeric Variables:**

# %%
# Creating histograms to visualise the distribution of data of the different numeric variables

# %%
# For variable Sales
plt.figure(figsize=(5,5))
plt.hist(df['Sales'],bins=10)
plt.xlabel('Sales')
plt.ylabel('Record')
plt.title('Sales Visualisation')
plt.show()

# %% [markdown]
# **Insight: The *Sales* data is not normally distributed and is skewed more to the left.**

# %%
# For variable Quantity
plt.figure(figsize=(5,5))
plt.hist(df['Quantity'],bins=10)
plt.xlabel('Quantity')
plt.ylabel('Record')
plt.title('Quantity Visualisation')
plt.show()

# %% [markdown]
# **Insight: The *Quantity* data is not normally distributed and is also skewed more to the left.**

# %%
# For variable Discount
plt.figure(figsize=(5,5))
plt.hist(df['Discount'],bins=10)
plt.xlabel('Discount')
plt.ylabel('Record')
plt.title('Discount Visualisation')
plt.show()

# %% [markdown]
# **Insight: The *Discount* data is randomly distributed.**

# %%
# For variable Profit
plt.figure(figsize=(5,5))
plt.hist(df['Profit'],bins=10)
plt.xlabel('Profit')
plt.ylabel('Record')
plt.title('Profit Visualisation')
plt.show()

# %% [markdown]
# **Insight: The *Profit* data is normally distributed.**

# %% [markdown]
# ## **Variable-wise analysis:**

# %% [markdown]
# ### **1. Analysis based on modes of shipping-**

# %%
# No of sales made in first, second or standard class and on the same day respectively

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %%
# Graphical representation of the same

# %%
sns.countplot(x='Ship Mode', data=df)
plt.title('No of sales made per shipping mode')
# Out:
# Text(0.5, 1.0, 'No of sales made per shipping mode')

# %%
# Total sales and profits made per shipping mode

# %%
df.groupby(['Ship Mode'])['Sales','Profit'].sum().plot.bar(figsize=(10,5),
           title='Sales and Profits per Ship Mode',color=['#702963','#9966cc'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Insights:**
#
# **1. The maximum number of sales are made through the Standard Class shipping mode.**
#
# **2. The maximum sales amount and profit is made when itmes are shipped through the Standard Class shipping mode.**

# %%
# No of sales made in first, second or standard class and on the same day respectively and the segments they are shipped to

# %%
sns.countplot(x='Ship Mode', hue='Segment', data=df, palette='Paired_r')
plt.title('No of sales made per shipping mode per segment')
# Out:
# Text(0.5, 1.0, 'No of sales made per shipping mode per segment')

# %%
# Total sales and profits made per shipping mode when Segment is taken into consideration

# %%
df.groupby(['Ship Mode','Segment'])['Sales','Profit'].sum().plot.bar(figsize=(14,6),
          title='Sales and Profits per Ship Mode per Segment',color=['#702963','#9966cc'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Insights:**
#
# **1. The maximum number of sales are made through the Standard Class shipping mode to the Consumer segment, while the minimum number of sales are made to the Home Office segment when shipped on the Same Day.**
#
# **2. The maximum sales amount is made when items are shipped through the Standard Class shipping mode to the Consumer segment and minimum sales amount is made when the items are shipped to the Home Office segment on the Same Day.**
#
# **3. The maximum profit is made when items are shipped through the Standard Class shipping mode to the Consumer segment and minimum profit is made when the items are shipped to the Corporate segment on the Same Day.**

# %%
# No of sales made in first, second or standard class and on the same day respectively and the regions they are shipped to

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Ship Mode', hue='Region', data=df, palette='Paired')
plt.title('No of sales made per shipping mode in respective regions')
# Out:
# Text(0.5, 1.0, 'No of sales made per shipping mode in respective regions')

# %%
# Total sales and profits made per shipping mode when Region is taken into consideration

# %%
df.groupby(['Ship Mode','Region'])['Sales','Profit'].sum().plot.bar(figsize=(14,6),
           title='Sales and Profits per Ship Mode per Region',color=['#702963','#9966cc'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Insights:**
#
# **1. The maximum number of sales are made through the Standard Class shipping mode to the Western region, while the minimum number of sales are made to the Southern region when shipped on the Same Day.**
#
# **2. The maximum sales amount is made when items are shipped through the Standard Class shipping mode to the Western region and minimum sales amount is made when the items are shipped to the Central region on the Same Day.**
#
# **3. The maximum profit is made when items are shipped through the Standard Class shipping mode to the Eastern Region and minimum profit is made when the items are shipped to the Southern region on the Same Day.**

# %% [markdown]
# ### **2. Analysis based on segments-**

# %%
# No of uniques segments 
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %% [markdown]
# So, there are 3 unique segments namely, Consumer, Corporate and Home office.

# %%
# No of sales made to the respective segments
df['Segment'].value_counts()
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
# Graphical representation of the same

# %%
sns.countplot(x='Segment',data=df, palette='autumn_r')
plt.title('No of sales per segment')
# Out:
# Text(0.5, 1.0, 'No of sales per segment')

# %%
# Sales and profits made per segment

# %%
df.groupby(['Segment'])['Sales','Profit'].sum().plot.bar(figsize=(10,5),
          title='Sales and Profits vs Segment',color=['#7f1734','#de1738'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Insights:**
#
# **1. The maximum number of sales are made to the Consumer segment, while the minimum number of sales are made to the Home Office Segment.**
#
# **2. The maximum sales amount is made in the Consumer segment and minimum sales amount is made in the Home Office segment.**
#
# **3. The maximum profit is made in the Consumer segment and minimum profit is made in the Home Office segment.**

# %%
# No of sales made per segment and the region they lie in

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Segment',hue='Region',data=df, palette='autumn')
plt.title('No of sales made per Segment per Region')
# Out:
# Text(0.5, 1.0, 'No of sales made per Segment per Region')

# %%
# Sales and profits made per Segment when the Region is considered

# %%
df.groupby(['Segment','Region'])['Sales','Profit'].sum().plot.bar(figsize=(12,6),
          title='Sales and Profits per Segment per Region',color=['#7f1734','#de1738'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Insights:**
#
# **1. The maximum number of sales are made in the Consumer segment to the Western region, while the minimum number of sales are made to the Southern region in the Home Office segment.**
#
# **2. The maximum sales amount is made in the Consumer segment the Western region and minimum sales amount is made in the Home Office segment in the Southern region.**
#
# **3. The maximum profit is made in the Consumer segment in the Western Region and minimum profit is made in the Home Office segment in the Southern region.**

# %% [markdown]
# ### **3. Analysis based on City, State and Postal Codes-**

# %% [markdown]
# **City:**

# %%
# No of unique cities we have in the dataset

# %%
df['City'].nunique()
# Out:
# 531

# %% [markdown]
# There are 531 unique cities in the dataset.
# Since it's not possible to work with all the cities, we will see the 10 cities with the maximum and minimum number of sales, highest and lowest sales amount and the maximum and minimum profits respectively.

# %%
# Top 10 cities with maximum no of sales

# %%
print('The top 10 cities with the maximum no of sales are: ')
df['City'].value_counts().head(10)
# Out:
# The top 10 cities with the maximum no of sales are:
# New York City    914
# Los Angeles      746
# Philadelphia     536
# San Francisco    506
# Seattle          424
# Houston          375
# Chicago          313
# Columbus         221
# San Diego        170
# Springfield      163
# Name: City, dtype: int64

# %%
# We can represent the 10 cities with the maximum no of sales on a graph

# %%
plt.figure(figsize=(14,6))
plt.plot(df['City'].value_counts().head(10),color='#006400')
plt.xlabel('Cities')
plt.ylabel('No of sales')
plt.title('Top 10 cities with the maximum no of sales')
plt.show()

# %%
# 10 cities with the minimum no of sales

# %%
print('The 10 cities with the least sales are: ')
df['City'].value_counts().tail(10)
# Out:
# The 10 cities with the least sales are:
# Goldsboro          1
# Missoula           1
# Melbourne          1
# Whittier           1
# Santa Maria        1
# San Luis Obispo    1
# Kissimmee          1
# Jefferson City     1
# Citrus Heights     1
# Montebello         1
# Name: City, dtype: int64

# %%
# We can represent the 10 cities with the minimum no of sales on a graph

# %%
plt.figure(figsize=(14,6))
plt.plot(df['City'].value_counts().tail(10),color='#8b0000')
plt.xlabel('Cities')
plt.ylabel('No of sales')
plt.title('10 cities with the minimum no of sales')
plt.show()

# %%
# Top 10 cities with the highest total sales amount

# %%
print('The top 10 cities with the highest total sales amount are: ')
pd.pivot_table(df,index=['City'],values=['Sales'],aggfunc=np.sum).sort_values(by='Sales',ascending=False).head(10)
# Out:
# The top 10 cities with the highest total sales amount are:
#                      Sales
# City
# New York City  256319.0410
# Los Angeles    175831.9010
# Seattle        119460.2820
# San Francisco  112577.1720
# Philadelphia   109061.4610
# Houston         64441.2564
# Chicago         48535.9770
# San Diego       47521.0290
# Jacksonville    44713.1830
# Springfield     43054.3420

# %%
# We can represent them on a graph

# %%
plt.figure(figsize=(14,6))
plt.plot(pd.pivot_table(df,index=['City'],values=['Sales'],aggfunc=np.sum).sort_values(by='Sales',
            ascending=False).head(10),color='#006400')
plt.xlabel('Cities')
plt.ylabel('Total Sales Amount')
plt.title('Top 10 cities with the highest total sales amount')
plt.show()

# %%
# 10 cities with the lowest total sales amount

# %%
print('10 cities with the lowest total sales amount are: ')
pd.pivot_table(df,index=['City'],values=['Sales'],aggfunc=np.sum).sort_values(by='Sales',ascending=False).tail(10)
# Out:
# 10 cities with the lowest total sales amount are:
#                  Sales
# City
# Missouri City    6.370
# Keller           6.000
# Layton           4.960
# Springdale       4.300
# San Luis Obispo  3.620
# Ormond Beach     2.808
# Pensacola        2.214
# Jupiter          2.064
# Elyria           1.824
# Abilene          1.392

# %%
# We can represent them on a graph

# %%
plt.figure(figsize=(14,6))
plt.plot(pd.pivot_table(df,index=['City'],values=['Sales'],aggfunc=np.sum).sort_values(by='Sales',
            ascending=False).tail(10),color='#8b0000')
plt.xlabel('Cities')
plt.ylabel('Total Sales Amount')
plt.title('10 Cities with the lowest total sales amount')
plt.show()

# %%
# Top 10 cities with maximum profits

# %%
print('The top 10 cities with the maximum profits are: ')
pd.pivot_table(df,index=['City'],values=['Profit'],aggfunc=np.sum).sort_values(by='Profit',ascending=False).head(10)
# Out:
# The top 10 cities with the maximum profits are:
#                    Profit
# City
# New York City  62013.8973
# Los Angeles    30431.4267
# Seattle        29121.6825
# San Francisco  17466.1186
# Detroit        13146.6935
# Lafayette      10018.3876
# Jackson         7581.6828
# Atlanta         6993.6629
# Minneapolis     6824.5846
# San Diego       6377.1960

# %%
# Graphical representation for the same

# %%
profit_graph=pd.pivot_table(df,index=['City'],values=['Profit'],aggfunc=np.sum).sort_values(by='Profit',ascending=False).head(10)
profit_graph.plot.bar(figsize=(12,6),color='green')

# %%
# Cities undergoing losses

# %%
print('10 cities making the least profits or in other words, undergoing losses, are: ')
pd.pivot_table(df,index=['City'],values=['Profit'],aggfunc=np.sum).sort_values(by='Profit',ascending=False).tail(10)
# Out:
# 10 cities making the least profits or in other words, undergoing losses, are:
#                   Profit
# City
# Jacksonville  -2323.8350
# Aurora        -2691.7386
# Phoenix       -2790.8832
# Dallas        -2846.5257
# Burlington    -3622.8772
# Chicago       -6648.3318
# Lancaster     -7239.0684
# San Antonio   -7299.0502
# Houston      -10175.1755
# Philadelphia -13843.2106

# %%
# Graphical representation for the same

# %%
loss_graph=pd.pivot_table(df,index=['City'],values=['Profit'],aggfunc=np.sum).sort_values(by='Profit',ascending=False).tail(10)
loss_graph.plot.bar(figsize=(12,6),color='#8b0000')

# %% [markdown]
# **Insights:**
#
# **1. The maximum number of sales are made to New York City and, the minimum number of sales are made to a number of cities like Iowa City,Rochester Hills, Pensacola, Montebello and Deer Park and a few others.**
#
# **2. The maximum sales amount is made in New York City and the minimum sales amount is made in Abilene.**
#
# **3. The maximum profit is made in New York City and minimum profit or maximum loss is incurred by Philadelphia.**
#
# **4. We note that Philadelphia despite being one of the top 5 cities to have the maximum number of sales and sales amounts still incurs the most loss. This shows that having maximum no of sales doesn't mean it will help get profits or vice versa.**

# %% [markdown]
# **State:**

# %%
# No of unique states in the dataset

# %%
df['State'].nunique()
# Out:
# 49

# %% [markdown]
# So there are 49 unique states in the given dataset

# %%
# We represen the no of sales made per state on a graph first

# %%
plt.figure(figsize=(18,6))
sns.countplot(x=df['State'], palette='autumn')
plt.xticks(rotation=75)
plt.show()

# %%
print('The top 5 states with the maximum no of sales')
df['State'].value_counts().head() # Gives the top 5 states with the maximum no of sales
# Out:
# The top 5 states with the maximum no of sales
# California      1996
# New York        1127
# Texas            983
# Pennsylvania     586
# Washington       502
# Name: State, dtype: int64

# %%
print('The 5 states with the minimum no of sales')
df['State'].value_counts().tail() # Gives the 5 states with the minimum no of sales
# Out:
# The 5 states with the minimum no of sales
# District of Columbia    10
# Maine                    8
# North Dakota             7
# West Virginia            4
# Wyoming                  1
# Name: State, dtype: int64

# %% [markdown]
# **Insights- As we can see from the graph and verify through the formulas as well, the maximum number of sales are made in the state of California and minimum number of sales are made in the state of Wyoming.**

# %%
# States with the highest and lowest total sales amount

# %%
# First, we plot all the states with their respective total sales amount on a graph
State_sales=pd.pivot_table(df,index=['State'],values=['Sales'],aggfunc=np.sum)
State_sales.plot.bar(figsize=(12,10),color='#e75480')

# %%
print('The top 5 states with the highest sales amount is : ')
pd.pivot_table(df,index=['State'],values=['Sales'],aggfunc=np.sum).sort_values(by='Sales',ascending=False).head()
# Out:
# The top 5 states with the highest sales amount is :
#                     Sales
# State
# California    457576.2715
# New York      310827.1510
# Texas         170124.5418
# Washington    138560.8100
# Pennsylvania  116496.3620

# %%
print('The 5 states with the lowest sales amount are: ')
pd.pivot_table(df,index=['State'],values=['Sales'],aggfunc=np.sum).sort_values(by='Sales',ascending=False).tail()
# Out:
# The 5 states with the lowest sales amount are:
#                   Sales
# State
# Wyoming        1603.136
# South Dakota   1315.560
# Maine          1270.530
# West Virginia  1209.824
# North Dakota    919.910

# %% [markdown]
# **Insights- As we can see from the graph and verify through the formulas as well, the maximum sales amount is made in the state of California and minimum sales amount is made in the state of North Dakota.**

# %%
# States with the maximum and minimum profits

# %%
# Plotting all the states with their respective profits on a graph
State_profits=pd.pivot_table(df,index=['State'],values=['Profit'],aggfunc=np.sum)
State_profits.plot.bar(figsize=(12,10),color='#fc8eac')

# %%
print('The top 5 states with the maximum profits are: ')
pd.pivot_table(df,index=['State'],values=['Profit'],aggfunc=np.sum).sort_values(by='Profit',ascending=False).head()
# Out:
# The top 5 states with the maximum profits are:
#                 Profit
# State
# California  76330.7891
# New York    74015.4622
# Washington  33368.2375
# Michigan    24428.0903
# Virginia    18597.9504

# %%
print('The 5 states with the minimum profits or in other words, undergoing losses, are: ')
pd.pivot_table(df,index=['State'],values=['Profit'],aggfunc=np.sum).sort_values(by='Profit',ascending=False).tail()
# Out:
# The 5 states with the minimum profits or in other words, undergoing losses, are:
#                     Profit
# State
# North Carolina  -7490.9122
# Illinois       -12601.6500
# Pennsylvania   -15565.4035
# Ohio           -16959.3178
# Texas          -25750.9833

# %% [markdown]
# **Insights- As we can see from the graph and verify through the formulas as well, the maximum profit is made in the state of California and minimum profit is made in the state of Texas.**
#
# **Note that- Texas is one of the top 3 states to have the maximum number of sales and sales amount, but it is also the state to incur the most losses. So once again, having the maximum sales or sales amount doesn't always ensure one's profit and vice versa.**

# %% [markdown]
# **Postal Code:**

# %%
# No of unique postal codes in the dataset

# %%
df['Postal Code'].nunique()
# Out:
# 631

# %% [markdown]
# There are 631 unique postal codes. We will just find out which 5 postal code areas have the maximum and minimum number of sales, highest and lowest (total) sales amount and maximum and minimum profits respectively.

# %%
# The postal code areas with the maximum and minimum no of sales

# %%
print('The top 5 postal code areas with the maximum no of sales are')
df['Postal Code'].value_counts().head()
# Out:
# The top 5 postal code areas with the maximum no of sales are
# 10035    263
# 10024    230
# 10009    229
# 94122    199
# 10011    192
# Name: Postal Code, dtype: int64

# %%
print('The 5 postal code areas with the minimum no of sales are')
df['Postal Code'].value_counts().tail()
# Out:
# The 5 postal code areas with the minimum no of sales are
# 33458    1
# 95616    1
# 48307    1
# 61832    1
# 59102    1
# Name: Postal Code, dtype: int64

# %%
# The postal code areas with the highest and lowest total sales amount

# %%
print('The top 5 postal code areas with the highest sales amount are : ')
pd.pivot_table(df,index=['Postal Code'],values=['Sales'],aggfunc=np.sum).sort_values(by='Sales',ascending=False).head()
# Out:
# The top 5 postal code areas with the highest sales amount are :
#                  Sales
# Postal Code
# 10024        78697.182
# 10035        77357.885
# 10009        54761.496
# 94122        52575.547
# 10011        45502.478

# %%
print('The 5 postal code areas with the lowest sales amount are : ')
pd.pivot_table(df,index=['Postal Code'],values=['Sales'],aggfunc=np.sum).sort_values(by='Sales',ascending=False).tail()
# Out:
# The 5 postal code areas with the lowest sales amount are :
#              Sales
# Postal Code
# 32174        2.808
# 32503        2.214
# 33458        2.064
# 44035        1.824
# 79605        1.392

# %%
# The postal code areas with the maximum and minimum profits

# %%
print('The top 5 postal code areas with the maximum profits are: ')
pd.pivot_table(df,index=['Postal Code'],values=['Profit'],aggfunc=np.sum).sort_values(by='Profit',ascending=False).head()
# Out:
# The top 5 postal code areas with the maximum profits are:
#                  Profit
# Postal Code
# 10024        21653.7248
# 10035        16533.8669
# 10009        13697.0019
# 98115        13297.6547
# 10011        10129.3037

# %%
print('The 5 postal code areas with the minimum profits are: ')
pd.pivot_table(df,index=['Postal Code'],values=['Profit'],aggfunc=np.sum).sort_values(by='Profit',ascending=False).tail()
# Out:
# The 5 postal code areas with the minimum profits are:
#                 Profit
# Postal Code
# 19140       -5168.3905
# 60653       -5672.5612
# 27217       -5894.5269
# 43130       -7149.6180
# 78207       -7299.0502

# %% [markdown]
# **Insights:**
#
# **1. The maximum number of sales are made in the postal code area 10035 and, the minimum number of sales are made in the postal code area 59102.**
#
# **2. The maximum sales amount is made in the postal code area 10024 and the minimum sales amount is made in the postal code area 79605.**
#
# **3. The maximum profit is made in the area 10024 and minimum profit or maximum loss is the postal code area 78207.**

# %% [markdown]
# ### **4. Analysis based on Region-**

# %%
# No of unique regions and count of items per region

# %%
df['Region'].value_counts()
# Out:
# West       3193
# East       2845
# Central    2319
# South      1620
# Name: Region, dtype: int64

# %%
# Graphical representation for the no of sales per region

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='Region',data=df, palette='rocket')
plt.title('No of sales made per Region')
plt.show()

# %%
# Plotting sales and profits per region

# %%
df.groupby(['Region'])['Sales','Profit'].sum().plot.bar(figsize=(10,5),
          title='Sales and Profits vs Region',color=['#228b22','#9acd32'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Insights:**
#
# **1. The maximum number of sales are made in the Western region, while the minimum number of sales are made in the Southern region.**
#
# **2. The maximum sales amount is made in the Western region and minimum sales amount is made in the Southern region.**
#
# **3. The maximum profit is made in the Western Region and minimum profit is made in the Central region.**

# %% [markdown]
# ## **5. Analysis on the basis of Category and Sub-category-**

# %% [markdown]
# **Category:**

# %%
# No of unique categories

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %% [markdown]
# There are 3 unique categories of sales items namely, Furniture, Office Supplies and Technology.

# %%
# No of itmes per category

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %%
# Plotting the no of items per category on a graph

# %%
sns.countplot(x='Category', data=df, palette='rocket')
plt.title('No of sales per category')
plt.show()

# %%
# Total Sales and Profit per category

# %%
df.groupby(['Category'])['Sales','Profit'].sum().plot.bar(figsize=(10,5),
          title='Sales and Profits vs Category',color=['#800020','#e32636'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Insights:**
#
# **1. The maximum number of sales are made from the Office Supplies category while the minimum number of sales are made from the Technology category.**
#
# **2. The maximum sales amount is made in the Technology category and minimum sales amount is made in the Office Supplies category.**
#
# **3. The maximum profit is made in the Technology category and minimum profit is made in the Furniture categor**y.
#
# **Note that: The Technology department, despite having the least no of sales, still makes the most sales amount and profit. This is probably because the cost of the technology items is more than those of the Office Supplies or Furniture items and hence, even though the sale is less, they manage to make the maximum sales amount and profits.Similarly, the Office Supplies department, in spite of having the most number of sales, fails to get a total sales amount or a profit as much as that of the Technology department.**

# %%
# Plotting the no of sales made per category on a graph when the shipping mode is considered

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Category', data=df, hue='Ship Mode', palette='Blues_r')
plt.title('No of sales made per category per ship mode')
plt.show()

# %%
# Total sales and profit per category per shipping mode

# %%
df.groupby(['Category','Ship Mode'])['Sales','Profit'].sum().plot.bar(figsize=(10,5),
            title='Sales and Profits per Category per Ship Mode',color=['#000080','#6495ed'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Insights:**
#
# **1. The maximum number of sales are made in the Office Supplies category when shipped through Standard Class,while the minimum number of sales are made in the Technology category when shipped on the Same Day.**
#
# **2. The maximum sales amount is made in the Technology category when shipped through Standard Class and the minimum sales amount is made in the Office Supplies category when shipped on the Same Day.**
#
# **3. The maximum profit is made in the Technology category when shipped through Standard Class while the minimum profit or maximum loss is incurred by the Furniture category when shipped on the Same Day.**

# %%
# Plotting the no of items per category on a graph when the segments are considered

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Category', data=df, hue='Segment', palette='Greens')
plt.title('No of sales made per category per segment')
plt.show()

# %%
# Total sales and profit per category per segment

# %%
df.groupby(['Category','Segment'])['Sales','Profit'].sum().plot.bar(figsize=(10,5),
           title='Sales and Profits per Category per Segment',color=['#228b22','#4cbb17'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Insights:**
#
# **1. The maximum number of sales are made in the Office Supplies category in the Consumer segment,while the minimum number of sales are made in the Technology category in the Home Office segment.**
#
# **2. The maximum sales amount is made in the Technology category in the Consumer segment and the minimum sales amount is made in the Furniture category in the Home Office segment**.
#
# **3. The maximum profit is made in the Technology category in the Consumer segment while the minimum profit or maximum loss is incurred by the Furniture category in the Home Office segment.**

# %%
# Plotting the no of items per category on a graph when the regions are considered

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Category', data=df, hue='Region', palette='Oranges_r')
plt.title('No of sales made per category per region')
plt.show()

# %%
# Total sales and profit per category per region

# %%
df.groupby(['Category','Region'])['Sales','Profit'].sum().plot.bar(figsize=(10,5),
          title='Sales and Profits per Category per Region',color=['#cc5500','#ffa500'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Insights:**
#
# **1. The maximum number of sales are made in the Office Supplies category in the Western region,while the minimum number of sales are made in the Technology category in the Southern region.**
#
# **2. The maximum sales amount is made in the Technology category in the Eastern region and the minimum sales amount is made in the Furniture category in the Southern region.**
#
# **3. The maximum profit is made in the Office Supplies Categories in the Western region while the minimum profit or maximum loss is incurred by the Furniture category in the Central region.**

# %% [markdown]
# **Sub-category:**

# %%
# No of unique sub categories

# %%
df['Sub-Category'].nunique()
# Out:
# 17

# %% [markdown]
# So there are 17 unique sub-categories in the given dataset.

# %%
# No of sales made per sub-category (highest to lowest)

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1522
# Paper          1359
# Furnishings     956
# Phones          889
# Storage         846
# Art             795
# Accessories     775
# Chairs          615
# Appliances      466
# Labels          363
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
# Plotting the no of sales made per sub-category

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Sub-Category', data=df, palette='flare')
plt.title('No of sales made per sub-category')
plt.xticks(rotation=75)
plt.show()

# %%
# Sales and Profits made per sub-category

# %%
df.groupby(['Sub-Category'])['Sales','Profit'].sum().plot.bar(figsize=(12,6), 
          title='Sales and Profit per sub-category', color=['#800000','#FF0000'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Insights:**
#
# **1. Binders are the most sold items while copiers are the least sold.**
#
# **2. The maximum sales amount is made by selling Phones and the minimum sales amount is made by selling Fasteners.**
#
# **3. The maximum profit is made by selling Copiers while the minimum profit or maximum loss is incurred by the sale of Tables.**

# %%
# No of sales made per sub-category per ship mode

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Sub-Category',hue='Ship Mode',data=df, palette='rocket')
plt.title('No of sales made per sub-category per ship mode')
plt.xticks(rotation=90)
plt.show()

# %%
# Sales and Profits made per sub-category per ship mode

# %%
df.groupby(['Sub-Category','Ship Mode'])['Sales','Profit'].sum().plot.barh(figsize=(8,20),
            title='Sales and Profits per sub-category per ship mode',color=['#5B2C6F','#C1355D'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Insights:**
#
# **1. Binders are the most sold items,shipped through Standard Class while copiers are the least sold, shipped on the Same Day.**
#
# **2. The maximum sales amount is made by selling Phones,shipped through Standard Class and the minimum sales amount is obtained on selling Fasteners, shipped on the Same Day.**
#
# **3. The maximum profit is made by selling Copiers,shipped through Standard Class while the minimum profit or maximum loss is incurred by the sale of Tables,shipped through Standard Class.**

# %%
# No of sales made per sub-category per segment

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Sub-Category',hue='Segment',data=df, palette='autumn_r')
plt.title('No of sales made per sub-category per segment')
plt.xticks(rotation=90)
plt.show()

# %%
# Sales and Profits made per sub-category per segment

# %%
df.groupby(['Sub-Category','Segment'])['Sales','Profit'].sum().plot.barh(figsize=(8,20),
            title='Sales and Profits per sub-category per segment',color=['#DD6A11','#C1355D'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Insights:**
#
# **1. Binders are the most sold items in the Consumer Segment while copiers are the least sold items in the Home Office segment.**
#
# **2. The maximum sales amount is made by selling Chairs,in the Consumer Segment and the minimum sales amount is obtained on selling Fasteners, in the Home Office segment.**
#
# **3. The maximum profit is made by selling Copiers,in the Consumer segment while the minimum profit or maximum loss is incurred by the sale of Tables,in the Consumer segment.**

# %%
# No of sales made per sub-category per region

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Sub-Category',hue='Region',data=df, palette='flare')
plt.title('No of sales made per sub-category per Region')
plt.xticks(rotation=90)
plt.show()

# %%
# Sales and Profits made per sub-category per region

# %%
df.groupby(['Sub-Category','Region'])['Sales','Profit'].sum().plot.barh(figsize=(8,20),
           title='Sales and Profits per sub-category per region',color=['#0D700A','#0C08EA'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Insights:**
#
# **1. Binders are the most sold items in the Western region while copiers are the least sold items in the Southern region.**
#
# **2. The maximum sales amount is made by selling Chairs,in the Western region and the minimum sales amount is obtained on selling Fasteners, in the Southern region.**
#
# **3. The maximum profit is made by selling Copiers,in the Western region while the minimum profit or maximum loss is incurred by the sale of Tables,in the Eastern region.**

# %% [markdown]
# **Category and Sub-Category combined:**

# %%
# Comparing Sales and Profit for Sub-Category per Category

# %%
pd.pivot_table(df,index=['Category','Sub-Category'], values=['Sales','Profit'],aggfunc=np.sum).plot.bar(
    figsize=(16,8),title='Comparing sales and profit Category and Sub-Category wise')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# **Insights:**
#
# **1. The maximum sales amount is made by selling Phones which belong to the Technology category and the minimum sales amount is obtained on selling Fasteners, belonging to the Office Supplies category.**
#
# **2. The maximum profit is made by selling Copiers, belonging to the Technology category while the minimum profit or maximum loss is incurred by the sale of Tables,belonging to the Furniture category.**

# %% [markdown]
# ## **6. Analysis based on Quantity-**

# %%
# No of items ordered per Category

# %%
pd.pivot_table(df,index=['Category'],values=['Quantity'],aggfunc=np.sum)
# Out:
#                  Quantity
# Category
# Furniture            8020
# Office Supplies     22861
# Technology           6939

# %%
# We can represent the same on a graph

# %%
pd.pivot_table(df,index=['Category'],values=['Quantity'],aggfunc=np.sum).plot.barh(figsize=(8,4),
               title='No (Quantiy) of items shipped per category',color='#451189')

# %%
# No of items shipped per sub-category per category

# %%
pd.pivot_table(df,index=['Category','Sub-Category'], values=['Quantity'],aggfunc=np.sum)
# Out:
#                               Quantity
# Category        Sub-Category
# Furniture       Bookcases          868
#                 Chairs            2351
#                 Furnishings       3560
#                 Tables            1241
# Office Supplies Appliances        1729
#                 Art               2996
#                 Binders           5971
#                 Envelopes          906
#                 Fasteners          914
#                 Labels            1396
#                 Paper             5144
#                 Storage           3158
#                 Supplies           647
# Technology      Accessories       2976
#                 Copiers            234
#                 Machines           440
#                 Phones            3289

# %%
# We can represent the same on a graph

# %%
pd.pivot_table(df,index=['Category','Sub-Category'], values=['Quantity'],aggfunc=np.sum).plot.barh(figsize=(8,10),
              title='No (Quantity) of items shipped per sub-category per category',color='#3B5BFA')

# %% [markdown]
# **Insights:**
#
# **1. The maximum no of items ordered belong to the Office Supplies category and of the different Office Supplies items, Binders are ordered in maximum numbers.**
#
#   **The minimum no of items ordered belong to the Technology category and of the different Technology items, Copiers are ordered in minimum numbers.**

# %% [markdown]
# ## **7. Analysis based on discount-**

# %%
# Plotting the relationship between sales and discount

# %%
sales_vs_disc=pd.pivot_table(df,index=['Discount'],values=['Sales'],aggfunc=np.sum)
sales_vs_disc
# Out:
#                  Sales
# Discount
# 0.00      1.087278e+06
# 0.10      5.436935e+04
# 0.15      2.755852e+04
# 0.20      7.645049e+05
# 0.30      1.029453e+05
# 0.32      1.449346e+04
# 0.40      1.164178e+05
# 0.45      5.484974e+03
# 0.50      5.891854e+04
# 0.60      6.644700e+03
# 0.70      4.062028e+04
# 0.80      1.696019e+04

# %%
# Plotting the relation between sales and discount rates on a line graph

# %%
sales_vs_disc.plot(kind='line',figsize=(10,5),title='Sales vs Discount').legend()

# %%
# Plotting the relationship between profit and discount

# %%
profit_vs_disc=pd.pivot_table(df,index=['Discount'],values=['Profit'],aggfunc=np.sum)
profit_vs_disc
# Out:
#                Profit
# Discount
# 0.00      320844.4073
# 0.10        9029.1770
# 0.15        1418.9915
# 0.20       90306.6070
# 0.30      -10357.2186
# 0.32       -2391.1377
# 0.40      -23057.0504
# 0.45       -2493.1111
# 0.50      -20506.4281
# 0.60       -5944.6552
# 0.70      -40075.3569
# 0.80      -30532.8022

# %%
# Plotting the relation between profits and discount rates on a line graph

# %%
profit_vs_disc.plot(kind='line',figsize=(10,5),title='Profit vs Discount').legend()

# %% [markdown]
# **Insights:**
#
# **1. As we can see from the above graphs,both sales amounts and profit gradually decrease with the increase in discount rates. So in order to prevent that, discount rates must be checked so as to cut down any losses whatsoever**.

# %% [markdown]
# ## **Business Problems derived from the Data Exploration:**
# **As a business manager, we need to decide what steps can be taken to reduce any losses whatsoever. For instance**,
#
# **1. The Ship Mode Same Day needs to be either improved or dropped altogether since it incurs the most loss in any case**.
#
# **2. The Consumer segment is quite active while, the Home Office segment incurs losses in almost every case. In order to change that, we need to work on what's more in demand in that particular segment and provide items accordingly. We need to reconsider the pricing of the items that do sell in that segment so that we do not suffer from a loss in any case.**
#
# **3. Same goes for the regions. The Southern region has minimum sales and hence, minimum sales amount is obtained. In order to change this, we should either supply them with more items that they might require or increase the price of the items that do sell so that the total sales amount is improved. The Central region has more sales when compared to the Southern region and yet, it suffers from maximum losses. This must be because the discount rates there cut down any profit. So this is something to be looked at**.
#
# **4. For the cities,states and postal code areas, we need to note down which places have the least sales, sales amount and profits. And again, we need to sought out ways to improve the conditions there-by either providing more variety of items that they might require, increasing item prices(if required) or by reducing discount rates.**
#
# **5. As for the items of the different categories and sub-categories, we need to either reduce or increase the prices of some items while, we need to stop selling some things-like fasteners- altogether as they don't sell well anywhere. Whichever brings in business or profit at the end of the day.**
#
# **6.  We need to check the number of each item we have in our store because if we import more itmes than we can sell, it will lead to our loss.**
#
# **7. Finally, discounts must be offered at increased rates only when an item sells really well. So that is a must-check point.**
#
# ### **That's all the problems and their probable solutions we could find from this analysis.**
#
# # **Thank You.**
